# %% [markdown]
# Part 1: Power of Numpy vs Python List

# %%
import numpy as np

# %%
py_list = [i for i in range(10000)]
np_list = np.arange(10000)

# %%
# %%time
py_list = [i*5 for i in range(10000)]
# Out:
# CPU times: user 1.12 ms, sys: 0 ns, total: 1.12 ms
# Wall time: 1.19 ms

# %%
# %%time
np_list = np_list * 5
# Out:
# CPU times: user 0 ns, sys: 565 µs, total: 565 µs
# Wall time: 582 µs

# %% [markdown]
# Numpy list is faster than python list because numpy was built for C language and Python lists is easier than C lists...
