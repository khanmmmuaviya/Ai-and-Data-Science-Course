# %%
class PasswordManager ():
  def __init__(self, user_name, password):
    self.user_name = user_name
    self.__password = password


  def __check_username (self):
    user_name = input("Enter Your Username: ")
    if user_name == self.user_name:
      return True
    else:
      return False


  def __check_password (self):
    password = input("\nEnter Your Password: ")
    if password == self.__password:
      return True
    else:
      return False

  def pass_setter (self):
    if self.__check_username():
      if self.__check_password():
        new_pass = input("\nEnter new password: ")
        self.__password = new_pass
        print("\nPassword Updated Successfully")
      else:
        print("\nInvalid Password")
    else:
      print("\nInvalid Username")

# %%
acc = PasswordManager ('mmuaviya_khan', 'mai_nhi_btaunga')

# %%
acc.pass_setter()
# Out:
# Enter Your Username: mmuaviya_khan
#
# Enter Your Password: mai_nhi_btaunga
#
# Enter new password: mai_nahi_btaunga
#
# Password Updated Successfully
