# %%
class Animal ():
  def __init__ (self, sound):
    self.sound = sound
  def make_sound (self):
    return self.sound

class Dog (Animal):
  def __init__ (self,sound):
    super().__init__(sound)

# %%
dog = Dog("Barks")

# %%
dog.make_sound()
# Out:
# 'Barks'
